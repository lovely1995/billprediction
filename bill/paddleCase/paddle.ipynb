# %%
# import paddle
# gpu_available  = paddle.device.is_compiled_with_cuda()
# print("GPU available:", gpu_available)
# import torch

# print("CUDA available:", torch.cuda.is_available())

# %% [markdown]
# pip Version

# %% [markdown]
# paddleocr==2.7.0.3
# paddlepaddle==2.5.2
# paddlepaddle-gpu==2.5.2
# protobuf==3.20.2

# %% [markdown]
# 共用FUC

# %%
import fitz  # PyMuPDF
from PIL import Image, ImageDraw,ImageFont
def convertPdfToPng(pdf_path,tpe):
    # 打开PDF文件
    pdf_document = fitz.open(pdf_path)
    # 设置更高的分辨率（DPI）
    dpi = 300  # 可以根据需要调整
    for page_number in range(pdf_document.page_count):
        # 获取PDF页面
        page = pdf_document[page_number]

        # 获取页面尺寸（以点为单位）
        rect = page.rect

        # 将页面转换为图像
        #image = page.get_pixmap()
        # 将页面转换为图像，设置更高的分辨率
        image = page.get_pixmap(matrix=fitz.Matrix(dpi/72, dpi/72))
        # 将图像保存为PNG文件
        image.save(f"pic/{tpe}_page_{page_number + 1}.png", "PNG")

    # 关闭PDF文件
    pdf_document.close()

# %%
from paddleocr import PaddleOCR
def OCR (path):
    ocr = PaddleOCR(use_angle_cls=True, lang="ch")
    img_path = path
    result = ocr.ocr(img_path, cls=True)
    return result

# %%
import cv2
import os

def drawYoloBoxes(image_path,output_path, coordinates,label):
    # 讀取圖片
    image = cv2.imread(image_path)

    # 將座標轉換為整數
    coordinates = [(int(x), int(y)) for x, y in coordinates]

    # 繪製邊框
    color = (0, 255, 0)  # BGR格式，這裡使用綠色
    thickness = 2
    for i in range(len(coordinates) - 1):
        cv2.line(image, coordinates[i], coordinates[i + 1], color, thickness)
    cv2.line(image, coordinates[-1], coordinates[0], color, thickness)

    # 在圖片上寫上文字
    font = cv2.FONT_HERSHEY_SIMPLEX
    font_scale = 0.5
    font_thickness = 1

    # 計算文字區域大小
    text_size = cv2.getTextSize(label, font, font_scale, font_thickness)[0]
    text_width, text_height = text_size[0], text_size[1]

    # 設定文字底色區域
    # 設定文字底色區域，增加空間
    background_padding = 5  # 設定額外的空間
    rect_background = (
        (coordinates[0][0], coordinates[0][1] - text_height - background_padding),
        (coordinates[0][0] + text_width + background_padding, coordinates[0][1] + background_padding)
    )

    # 填充底色
    cv2.rectangle(image, rect_background[0], rect_background[1], color, thickness=cv2.FILLED)

    # 寫上文字
    text_position = (coordinates[0][0], coordinates[0][1] - 5)
    cv2.putText(image, label, text_position, font, font_scale, (0, 0, 0), font_thickness)  # 文字使用黑色



    
    # 保存結果
    cv2.imwrite(output_path, image)

# %%
def labelTarget(pureStr,content,res,out):
    # 将每个子列表的两个元素组成元组，并创建新的列表
    xy = [(point[0], point[1]) for point in content[0]]
    number = content[1][1]*100
    acc = "{:.5f}".format(number)
    label = f"{content[1][0]} {acc}%"  if pureStr==""  else f"{pureStr} {acc}%"
    
    drawYoloBoxes(res,out, xy, label)

# %%
import os
def findFile(path):
    if os.path.exists(path):
        return True
    else:
        return False

# %% [markdown]
# 電費單

# %%
#pdf轉png
convertPdfToPng("ori/1.pdf","ELE")

# %%
#電費
elePage1=OCR('pic/ELE_page_1.png')
elePage2=OCR('pic/ELE_page_2.png')
# Out:
# [2023/12/19 10:54:39] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\016967/.paddleocr/whl\\det\\ch\\ch_PP-OCRv4_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\016967/.paddleocr/whl\\rec\\ch\\ch_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='c:\\Users\\016967\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\paddleocr\\ppocr\\utils\\ppocr_keys_v1.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='C:\\Users\\016967/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, ocr=True, recovery=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='ch', det=True, rec=True, type='ocr', ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2023/12/19 10:54:42] ppocr DEBUG: dt_boxes num : 122, elapsed : 1.2552490234375
# [2023/12/19 10:54:44] ppocr DEBUG: cls num  : 122, elapsed : 1.917449712753296
# [2023/12/19 10:55:12] ppocr DEBUG: rec_res num  : 122, elapsed : 28.760026931762695
# [2023/12/19 10:55:12] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\016967/.paddleocr/whl\\det\\ch\\ch_PP-OCRv4_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\016967/.paddleocr/whl\\rec\\ch\\ch_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='c:\\Users\\016967\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\paddleocr\\ppocr\\utils\\ppocr_keys_v1.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='C:\\Users\\016967/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, ocr=True, recovery=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='ch', det=True, rec=True, type='ocr', ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2023/12/19 10:55:15] ppocr DEBUG: dt_boxes num : 121, elapsed : 0.9812791347503662
# [2023/12/19 10:55:17] ppocr DEBUG: cls num  : 121, elapsed : 2.1001133918762207
# [2023/12/19 10:55:52] ppocr DEBUG: rec_res num  : 121, elapsed : 34.80445170402527

# %%
elePage1
# Out:
# [[[[[1085.0, 208.0], [1930.0, 208.0], [1930.0, 259.0], [1085.0, 259.0]],
#    ('112年01月费證（高電力用户）', 0.9484211802482605)],
#   [[[1089.0, 278.0], [1760.0, 278.0], [1760.0, 329.0], [1089.0, 329.0]],
#    ('Jan. 2023 Payment Receipt', 0.9833667278289795)],
#   [[[229.0, 373.0], [498.0, 373.0], [498.0, 424.0], [229.0, 424.0]],
#    ('367004', 0.9958589673042297)],
#   [[[225.0, 435.0], [1233.0, 435.0], [1233.0, 486.0], [225.0, 486.0]],
#    ('苗栗縣三義鄉西湖村伯公坑39一1号（工務科）', 0.9248785376548767)],
#   [[[221.0, 490.0], [971.0, 490.0], [971.0, 541.0], [221.0, 541.0]],
#    ('裕隆汽車製造股份有限公司三義工廠', 0.9654194116592407)],
#   [[[749.0, 628.0], [1048.0, 628.0], [1048.0, 679.0], [749.0, 679.0]],
#    ('先生/女士/實號', 0.8929145336151123)],
#   [[[1107.0, 632.0], [1690.0, 632.0], [1690.0, 669.0], [1107.0, 669.0]],
#    ('m21J009 m0112013000591', 0.9970155358314514)],
#   [[[1764.0, 625.0], [2321.0, 625.0], [2321.0, 672.0], [1764.0, 672.0]],
#    ('單據號碼：m0112013000591', 0.9387471079826355)],
#   [[[624.0, 683.0], [1181.0, 679.0], [1181.0, 752.0], [624.0, 756.0]],
#    ('缴費目期Payvment Date', 0.7589672207832336)],
#   [[[1222.0, 687.0], [1827.0, 687.0], [1827.0, 738.0], [1222.0, 738.0]],
#    ('费细全', 0.5057787895202637)],
#   [[[52.0, 731.0], [590.0, 731.0], [590.0, 793.0], [52.0, 793.0]],
#    ('电弧 Customer Number ', 0.8770284056663513)],
#   [[[627.0, 734.0], [1177.0, 727.0], [1178.0, 789.0], [628.0, 797.0]],
#    ('微真口期 Payment Date', 0.8476288318634033)],
#   [[[1225.0, 734.0], [1827.0, 734.0], [1827.0, 785.0], [1225.0, 785.0]],
#    ('誠具金1otal Amount', 0.7909765839576721)],
#   [[[1308.0, 781.0], [1724.0, 797.0], [1722.0, 859.0], [1306.0, 843.0]],
#    ('***4,293,261 元', 0.9369851350784302)],
#   [[[118.0, 797.0], [513.0, 793.0], [513.0, 847.0], [118.0, 851.0]],
#    ('21--64-3235-00-1', 0.9745336771011353)],
#   [[[786.0, 800.0], [1030.0, 800.0], [1030.0, 851.0], [786.0, 851.0]],
#    ('112/01/30', 0.9998401999473572)],
#   [[[989.0, 968.0], [1790.0, 968.0], [1790.0, 1019.0], [989.0, 1019.0]],
#    ('alWechageos', 0.6052687168121338)],
#   [[[48.0, 1027.0], [517.0, 1027.0], [517.0, 1078.0], [48.0, 1078.0]],
#    ('用后營利事業統一号：', 0.7929986119270325)],
#   [[[1023.0, 1019.0], [1311.0, 1027.0], [1309.0, 1082.0], [1022.0, 1074.0]],
#    ('基本電费(約定)', 0.9210275411605835)],
#   [[[1536.0, 1019.0], [1787.0, 1027.0], [1785.0, 1078.0], [1535.0, 1070.0]],
#    ('963600.0元', 0.9996207356452942)],
#   [[[709.0, 1030.0], [919.0, 1030.0], [919.0, 1070.0], [709.0, 1070.0]],
#    ('03489200', 0.9999032020568848)],
#   [[[1026.0, 1067.0], [1207.0, 1067.0], [1207.0, 1118.0], [1026.0, 1118.0]],
#    ('流動電費', 0.8645654916763306)],
#   [[[1511.0, 1059.0], [1791.0, 1067.0], [1789.0, 1129.0], [1509.0, 1121.0]],
#    ('3797841.8元', 0.9989908337593079)],
#   [[[48.0, 1070.0], [229.0, 1070.0], [229.0, 1122.0], [48.0, 1122.0]],
#    ('行業别：', 0.966877818107605)],
#   [[[598.0, 1070.0], [915.0, 1070.0], [915.0, 1122.0], [598.0, 1122.0]],
#    ('汽車製造業（301)', 0.8894378542900085)],
#   [[[2129.0, 1063.0], [2262.0, 1063.0], [2262.0, 1100.0], [2129.0, 1100.0]],
#    ('1', 0.5474462509155273)],
#   [[[44.0, 1114.0], [240.0, 1114.0], [240.0, 1165.0], [44.0, 1165.0]],
#    ('用電種類', 0.9657471179962158)],
#   [[[608.0, 1111.0], [925.0, 1103.0], [927.0, 1165.0], [610.0, 1173.0]],
#    ('特高需量電力', 0.9814317226409912)],
#   [[[1026.0, 1111.0], [1325.0, 1111.0], [1325.0, 1162.0], [1026.0, 1162.0]],
#    ('功率因數調整費', 0.9504610896110535)],
#   [[[1544.0, 1106.0], [1787.0, 1115.0], [1785.0, 1166.0], [1542.0, 1158.0]],
#    ('-71421.6元', 0.98567134141922)],
#   [[[1912.0, 1125.0], [2343.0, 1125.0], [2343.0, 1176.0], [1912.0, 1176.0]],
#    ('官網電子發票平台', 0.9602866172790527)],
#   [[[40.0, 1151.0], [945.0, 1147.0], [945.0, 1209.0], [41.0, 1213.0]],
#    ('用電地址：苗縣三羲鄉西湖村伯公坑39－1号', 0.9291395545005798)],
#   [[[1019.0, 1147.0], [1513.0, 1151.0], [1513.0, 1213.0], [1018.0, 1209.0]],
#    ('補收(退)金额(含停電扣减)', 0.8818274140357971)],
#   [[[1506.0, 1158.0], [1790.0, 1158.0], [1790.0, 1209.0], [1506.0, 1209.0]],
#    ('-404649.1元', 0.9989205598831177)],
#   [[[44.0, 1202.0], [354.0, 1202.0], [354.0, 1253.0], [44.0, 1253.0]],
#    ('契約容量（）', 0.9924882054328918)],
#   [[[1028.0, 1194.0], [1208.0, 1203.0], [1205.0, 1257.0], [1025.0, 1249.0]],
#    ('電器租費', 0.8101111650466919)],
#   [[[1591.0, 1198.0], [1790.0, 1198.0], [1790.0, 1249.0], [1591.0, 1249.0]],
#    ('7890.0元', 0.9997066855430603)],
#   [[[103.0, 1242.0], [439.0, 1242.0], [439.0, 1293.0], [103.0, 1293.0]],
#    ('經常（尖峰）契約', 0.9740980267524719)],
#   [[[812.0, 1249.0], [930.0, 1249.0], [930.0, 1290.0], [812.0, 1290.0]],
#    ('6000', 0.9996383190155029)],
#   [[[55.0, 1290.0], [354.0, 1290.0], [354.0, 1341.0], [55.0, 1341.0]],
#    ('最高需量（）', 0.9893720746040344)],
#   [[[1026.0, 1290.0], [1329.0, 1290.0], [1329.0, 1337.0], [1026.0, 1337.0]],
#    ('税前應缴總金额', 0.9550296664237976)],
#   [[[1517.0, 1290.0], [1790.0, 1290.0], [1790.0, 1341.0], [1517.0, 1341.0]],
#    ('4088820.0元', 0.9994083642959595)],
#   [[[103.0, 1333.0], [528.0, 1333.0], [528.0, 1385.0], [103.0, 1385.0]],
#    ('半尖峰（非夏月）需量', 0.9918428659439087)],
#   [[[808.0, 1333.0], [934.0, 1333.0], [934.0, 1385.0], [808.0, 1385.0]],
#    ('4870', 0.9997236728668213)],
#   [[[1030.0, 1333.0], [1162.0, 1333.0], [1162.0, 1385.0], [1030.0, 1385.0]],
#    ('營業税', 0.8079893589019775)],
#   [[[1543.0, 1333.0], [1794.0, 1333.0], [1794.0, 1385.0], [1543.0, 1385.0]],
#    ('204441.0元', 0.9999072551727295)],
#   [[[100.0, 1370.0], [406.0, 1370.0], [406.0, 1432.0], [100.0, 1432.0]],
#    ('调六半尖峰需量', 0.9287847876548767)],
#   [[[808.0, 1377.0], [937.0, 1377.0], [937.0, 1428.0], [808.0, 1428.0]],
#    ('4240', 0.9995561242103577)],
#   [[[103.0, 1421.0], [280.0, 1421.0], [280.0, 1472.0], [103.0, 1472.0]],
#    ('離峰需量', 0.9867392778396606)],
#   [[[1507.0, 1413.0], [1794.0, 1422.0], [1793.0, 1473.0], [1505.0, 1464.0]],
#    ('4,293,261元', 0.9938368797302246)],
#   [[[816.0, 1425.0], [941.0, 1425.0], [941.0, 1465.0], [816.0, 1465.0]],
#    ('1599', 0.9998053908348083)],
#   [[[1030.0, 1425.0], [1262.0, 1425.0], [1262.0, 1465.0], [1030.0, 1465.0]],
#    ('缴費總金额', 0.8658811450004578)],
#   [[[48.0, 1461.0], [919.0, 1461.0], [919.0, 1523.0], [48.0, 1523.0]],
#    ('計费度數（度） /Energy Consumption(kWh)', 0.930534839630127)],
#   [[[107.0, 1509.0], [280.0, 1509.0], [280.0, 1560.0], [107.0, 1560.0]],
#    ('尖峰度數', 0.9842408895492554)],
#   [[[886.0, 1512.0], [919.0, 1512.0], [919.0, 1553.0], [886.0, 1553.0]],
#    ('0', 0.992291271686554)],
#   [[[1882.0, 1505.0], [2137.0, 1505.0], [2137.0, 1556.0], [1882.0, 1556.0]],
#    ('輪流停電组别', 0.9165679812431335)],
#   [[[101.0, 1541.0], [322.0, 1550.0], [320.0, 1604.0], [99.0, 1596.0]],
#    ('半尖峰度數', 0.9507222175598145)],
#   [[[760.0, 1553.0], [926.0, 1553.0], [926.0, 1604.0], [760.0, 1604.0]],
#    ('956904', 0.9997832179069519)],
#   [[[1886.0, 1556.0], [2056.0, 1556.0], [2056.0, 1607.0], [1886.0, 1607.0]],
#    ('線代號', 0.9124540686607361)],
#   [[[2270.0, 1556.0], [2388.0, 1556.0], [2388.0, 1607.0], [2270.0, 1607.0]],
#    ('UF81', 0.9977502226829529)],
#   [[[101.0, 1585.0], [406.0, 1593.0], [405.0, 1648.0], [99.0, 1640.0]],
#    ('调六半尖峰度數', 0.8668204545974731)],
#   [[[786.0, 1596.0], [923.0, 1596.0], [923.0, 1648.0], [786.0, 1648.0]],
#    ('79832', 0.9995586276054382)],
#   [[[1886.0, 1604.0], [2137.0, 1604.0], [2137.0, 1655.0], [1886.0, 1655.0]],
#    ('每度燃料成本', 0.9992606043815613)],
#   [[[2200.0, 1604.0], [2384.0, 1604.0], [2384.0, 1655.0], [2200.0, 1655.0]],
#    ('2.6295元', 0.9999260902404785)],
#   [[[103.0, 1640.0], [284.0, 1640.0], [284.0, 1691.0], [103.0, 1691.0]],
#    ('離峰度數', 0.8659510612487793)],
#   [[[760.0, 1640.0], [926.0, 1640.0], [926.0, 1691.0], [760.0, 1691.0]],
#    ('313140', 0.9999129176139832)],
#   [[[1890.0, 1655.0], [2100.0, 1655.0], [2100.0, 1706.0], [1890.0, 1706.0]],
#    ('本期碳排量', 0.9987351298332214)],
#   [[[2144.0, 1655.0], [2377.0, 1655.0], [2377.0, 1706.0], [2144.0, 1706.0]],
#    ('687087 公斤', 0.9577362537384033)],
#   [[[56.0, 1680.0], [351.0, 1684.0], [350.0, 1735.0], [55.0, 1731.0]],
#    ('功率因數（%）', 0.9223874807357788)],
#   [[[828.0, 1686.0], [922.0, 1675.0], [928.0, 1730.0], [835.0, 1741.0]],
#    ('100', 0.9983139634132385)],
#   [[[1890.0, 1706.0], [2380.0, 1706.0], [2380.0, 1757.0], [1890.0, 1757.0]],
#    ('每度交再生基金0.0023元', 0.9997150301933289)],
#   [[[1018.0, 2126.0], [1745.0, 2119.0], [1746.0, 2170.0], [1019.0, 2177.0]],
#    ('代/專匯款帐号：00130160****', 0.9293176531791687)],
#   [[[1022.0, 2378.0], [1096.0, 2378.0], [1096.0, 2422.0], [1022.0, 2422.0]],
#    ('：', 0.9351451396942139)],
#   [[[1026.0, 2426.0], [1746.0, 2426.0], [1746.0, 2473.0], [1026.0, 2473.0]],
#    ('1.本費證各頂金额數字係由機器印出', 0.9017750024795532)],
#   [[[1022.0, 2473.0], [1790.0, 2469.0], [1790.0, 2521.0], [1022.0, 2524.0]],
#    ('如發現非機器列印或有改字者·概無', 0.9615236520767212)],
#   [[[1026.0, 2528.0], [1092.0, 2528.0], [1092.0, 2572.0], [1026.0, 2572.0]],
#    ('效·', 0.8496893644332886)],
#   [[[63.0, 2539.0], [764.0, 2539.0], [764.0, 2586.0], [63.0, 2586.0]],
#    ('本公司營利事業統—号：49813617', 0.8977389335632324)],
#   [[[1026.0, 2575.0], [1782.0, 2575.0], [1782.0, 2627.0], [1026.0, 2627.0]],
#    ('2.已由代機構完成扣缴或透過專属虚凝，', 0.8630083203315735)],
#   [[[2008.0, 2572.0], [2207.0, 2572.0], [2207.0, 2623.0], [2008.0, 2623.0]],
#    ('台湾電力公司', 0.9363213181495667)],
#   [[[52.0, 2608.0], [258.0, 2608.0], [258.0, 2659.0], [52.0, 2659.0]],
#    ('計費期間：', 0.7901297807693481)],
#   [[[454.0, 2616.0], [908.0, 2616.0], [908.0, 2663.0], [454.0, 2663.0]],
#    ('111/12/01至111/12/31', 0.9995753765106201)],
#   [[[1022.0, 2619.0], [1786.0, 2619.0], [1786.0, 2670.0], [1022.0, 2670.0]],
#    ('號完成費，兹收到上開電費無·特開列', 0.8882806897163391)],
#   [[[2033.0, 2627.0], [2188.0, 2627.0], [2188.0, 2667.0], [2033.0, 2667.0]],
#    ('1120130', 0.9999169707298279)],
#   [[[51.0, 2653.0], [275.0, 2640.0], [278.0, 2695.0], [54.0, 2708.0]],
#    ('本次抄表白', 0.8887277841567993)],
#   [[[705.0, 2652.0], [904.0, 2652.0], [904.0, 2692.0], [705.0, 2692.0]],
#    ('112/01/01', 0.9966856837272644)],
#   [[[1026.0, 2674.0], [1336.0, 2674.0], [1336.0, 2725.0], [1026.0, 2725.0]],
#    ('本缴費證為·', 0.888916015625)],
#   [[[2041.0, 2674.0], [2181.0, 2674.0], [2181.0, 2725.0], [2041.0, 2725.0]],
#    ('收款章', 0.999431312084198)],
#   [[[63.0, 2692.0], [280.0, 2692.0], [280.0, 2743.0], [63.0, 2743.0]],
#    ('下次抄表目', 0.8359025716781616)],
#   [[[703.0, 2684.0], [912.0, 2693.0], [910.0, 2748.0], [700.0, 2739.0]],
#    ('112/02/01', 0.9988760352134705)],
#   [[[273.0, 2700.0], [303.0, 2700.0], [303.0, 2736.0], [273.0, 2736.0]],
#    (':', 0.9573632478713989)],
#   [[[705.0, 2751.0], [1749.0, 2751.0], [1749.0, 2813.0], [705.0, 2813.0]],
#    ('@本聯為用户戴具及發票資訊·請妥善保存·以利?', 0.8458544015884399)],
#   [[[465.0, 2908.0], [557.0, 2908.0], [557.0, 2963.0], [465.0, 2963.0]],
#    ('本期', 0.9999858736991882)],
#   [[[764.0, 2908.0], [852.0, 2908.0], [852.0, 2963.0], [764.0, 2963.0]],
#    ('前期', 0.9998406171798706)],
#   [[[1605.0, 2922.0], [1845.0, 2922.0], [1845.0, 2963.0], [1605.0, 2963.0]],
#    ('載具類别（6位）', 0.8405866026878357)],
#   [[[107.0, 2966.0], [269.0, 2966.0], [269.0, 3007.0], [107.0, 3007.0]],
#    ('發票期别', 0.9926618933677673)],
#   [[[295.0, 2959.0], [554.0, 2959.0], [554.0, 3010.0], [295.0, 3010.0]],
#    ('112年01-02月', 0.999666690826416)],
#   [[[598.0, 2959.0], [852.0, 2959.0], [852.0, 3010.0], [598.0, 3010.0]],
#    ('111年11-12月', 0.9997865557670593)],
#   [[[103.0, 3010.0], [269.0, 3010.0], [269.0, 3061.0], [103.0, 3061.0]],
#    ('發票號碼', 0.8440586924552917)],
#   [[[303.0, 3010.0], [554.0, 3010.0], [554.0, 3061.0], [303.0, 3061.0]],
#    ('JG-55562325', 0.9998417496681213)],
#   [[[602.0, 3010.0], [852.0, 3010.0], [852.0, 3061.0], [602.0, 3061.0]],
#    ('GL-29130186', 0.9998273849487305)],
#   [[[118.0, 3061.0], [269.0, 3061.0], [269.0, 3112.0], [118.0, 3112.0]],
#    ('金额(元)', 0.98554527759552)],
#   [[[387.0, 3059.0], [551.0, 3049.0], [555.0, 3104.0], [390.0, 3113.0]],
#    ('4293261', 0.9999145865440369)],
#   [[[690.0, 3065.0], [849.0, 3065.0], [849.0, 3105.0], [690.0, 3105.0]],
#    ('4126524', 0.9999128580093384)],
#   [[[1997.0, 3072.0], [2185.0, 3072.0], [2185.0, 3109.0], [1997.0, 3109.0]],
#    ('年期别（5位）', 0.9699854254722595)],
#   [[[103.0, 3112.0], [1247.0, 3112.0], [1247.0, 3164.0], [103.0, 3164.0]],
#    ('本公司自112年1月1日起施新尖離峰時間带方案，挪移每-', 0.9545908570289612)],
#   [[[1985.0, 3105.0], [2288.0, 3105.0], [2288.0, 3153.0], [1985.0, 3153.0]],
#    ('戴真流水碼（10位）', 0.8544319272041321)],
#   [[[103.0, 3167.0], [1225.0, 3167.0], [1225.0, 3218.0], [103.0, 3218.0]],
#    ('至调六之尖離峰時間區段，方案完整内容請参本公司官網。', 0.9146299958229065)],
#   [[[1465.0, 3160.0], [1786.0, 3160.0], [1786.0, 3196.0], [1465.0, 3196.0]],
#    ('11201BBC2150134', 0.9977957010269165)],
#   [[[1978.0, 3259.0], [2203.0, 3259.0], [2203.0, 3299.0], [1978.0, 3299.0]],
#    ('核碼（15位）', 0.9526366591453552)],
#   [[[1469.0, 3310.0], [1794.0, 3310.0], [1794.0, 3346.0], [1469.0, 3346.0]],
#    ('219021643235001', 0.9993571043014526)],
#   [[[2244.0, 3427.0], [2358.0, 3427.0], [2358.0, 3481.0], [2244.0, 3481.0]],
#    ('296,1', 0.9986306428909302)]]]

# %%
#第一張
for line in elePage1:
    for word_info in line:
        # 提取文字和坐标
        worContent = word_info[1]
        xy = word_info[0]
        if '公斤' in worContent[0]:
            pureStr=worContent[0].replace(" ", "").replace("公斤", "")
            labelTarget(pureStr,word_info,"../target/ELE_show1.png","../target/ELE_show1.png")
            print(f"碳排 {pureStr}")
        if ('年' in worContent[0]) and ('月' in worContent[0]) and ('力' in worContent[0]):
            pureStr=worContent[0].replace(" ", "").split('年')[1].split('月')[0]
            labelTarget(pureStr,word_info,"pic/ELE_page_1.png","../target/ELE_show1.png")
            print(f"月份 {pureStr}")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[22], line 13
#      11 if ('年' in worContent[0]) and ('月' in worContent[0]) and ('力' in worContent[0]):
#      12     pureStr=worContent[0].replace(" ", "").split('年')[1].split('月')[0]
# ---> 13     labelTarget(pureStr,word_info,"pic/ELE_show1.png","../target/ELE_show1.png")
#      14     print(f"月份 {pureStr}")
#
# Cell In[5], line 8, in labelTarget(pureStr, content, res, out)
#       5 acc = "{:.5f}".format(number)
#       6 label = f"{content[1][0]} {acc}%"  if pureStr==""  else f"{pureStr} {acc}%"
# ----> 8 drawYoloBoxes(res,out, xy, label)
#
# Cell In[20], line 46, in drawYoloBoxes(image_path, output_path, coordinates, label)
#      40 cv2.putText(image, label, text_position, font, font_scale, (0, 0, 0), font_thickness)  # 文字使用黑色
#      45 # 保存結果
# ---> 46 cv2.imwrite(output_path, image)
#
# error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:801: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'

# %%
#第二張
for line in elePage2:
    i =0
    for word_info in line:

        # 提取文字和坐标
        worContent = word_info[1]

        #找出本期
        if '本期' in worContent[0] and len(worContent[0])==2:
            #本期的下兩個為數值
            word_info_target=line[i+2]
            labelTarget("",word_info_target,"pic/ELE_page_2.png","../target/ELE_show2.png")
            eleValue=word_info_target[1][0]
            print(f"度數 {eleValue}")
        
        i=i+1
# Out:
# 度數 1020628

# %% [markdown]
# 水費單

# %%
#pdf轉png
convertPdfToPng("ori/2023-9月自來水費0927.pdf","WATER")

# %%
#水費
waterPage1=OCR('pic/WATER_page_1.png')
# Out:
# [2023/12/06 16:20:15] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\016967/.paddleocr/whl\\det\\ch\\ch_PP-OCRv4_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\016967/.paddleocr/whl\\rec\\ch\\ch_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='c:\\Users\\016967\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\paddleocr\\ppocr\\utils\\ppocr_keys_v1.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='C:\\Users\\016967/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, ocr=True, recovery=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='ch', det=True, rec=True, type='ocr', ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2023/12/06 16:20:18] ppocr DEBUG: dt_boxes num : 105, elapsed : 1.1661489009857178
# [2023/12/06 16:20:19] ppocr DEBUG: cls num  : 105, elapsed : 1.610124111175537
# [2023/12/06 16:20:40] ppocr DEBUG: rec_res num  : 105, elapsed : 20.843254804611206

# %%
picPath="pic/WATER_page_1.png"
existPath="target/WATER_show1.png"
usePath =""

try:
    os.remove(existPath)
except:
    _=""
    
#第一張
for line in waterPage1: 
    i =0       
    for word_info in line:
        #
        if(findFile(existPath)): 
            usePath=existPath
        else:
            usePath=picPath

        # 提取文字和坐标
        worContent = word_info[1]
 
        #找出本期日期
        if '列印日期' in worContent[0] :
            labelTarget(worContent[0],word_info,usePath,existPath)
            eleValue=worContent[0].replace("列印日期","")
            print(f"月份 {eleValue}")


        if '本期實用' in worContent[0]:
        #本期的下兩個為數值
            word_info_target=line[i+1]
            #labelTarget("",word_info,usePath,existPath)
            labelTarget("",word_info_target,usePath,existPath)
            eleValue=word_info_target[1][0]
            print(f"度數 {eleValue}")
            
        if '本期' in worContent[0] and len( worContent[0])==2:
        #本期的下兩個為數值
            word_info_target=line[i+1]
            #labelTarget("",word_info,usePath,existPath)
            labelTarget("",word_info_target,usePath,existPath)
            eleValue=word_info_target[1][0]
            print(f"備用度數 {eleValue}")

        i=i+1
# Out:
# 月份 112.09.18
# 度數 291
# 備用度數 291
